# %% [markdown]
# <a href="https://colab.research.google.com/github/Shakestick/HelloWorld/blob/main/Country_Alphabet_Memory_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A two player  alphabet memory game where points are won for guessing countries and more points for guessing their capitals within ten seconds.


import random
import time

class AlphabetMemoryGame:
    def __init__(self):
        self.countries_capitals = {
            "Afghanistan": "Kabul",
            "Albania": "Tirana",
            "Algeria": "Algiers",
            "Andorra": "Andorra la Vella",
            "Angola": "Luanda",
            "Antigua and Barbuda": "Saint John's",
            "Argentina": "Buenos Aires",
            "Armenia": "Yerevan",
            "Australia": "Canberra",
            "Austria": "Vienna",
            "Azerbaijan": "Baku",
            "Bahamas": "Nassau",
            "Bahrain": "Manama",
            "Bangladesh": "Dhaka",
            "Barbados": "Bridgetown",
            "Belarus": "Minsk",
            "Belgium": "Brussels",
            "Belize": "Belmopan",
            "Benin": "Porto-Novo",
            "Bhutan": "Thimphu",
            "Belarus": "Minsk",
            "Bolivia": "La Paz",
            "Bosnia and Herzegovina": "Sarajevo",
            "Botswana": "Gaborone",
            "Brazil": "Brasilia",
            "Brunei": "Bandar Seri Begawan",
            "Bulgaria": "Sofia",
            "Burkina Faso": "Ouagadougou",
            "Burundi": "Bujumbura",
            "Cabo Verde": "Praia",
            "Cambodia": "Phnom Penh",
            "Cameroon": "Yaounde",
            "Canada": "Ottawa",
            "Central African Republic": "Bangui",
            "Chad": "N'Djamena",
            "Cape Verde": "Praia",
            "Chile": "Santiago",
            "Caiman Islands": "George Town",
            "China": "Beijing",
            "Colombia": "Bogota",
            "Comoros": "Moroni",
            "Congo": "Brazzaville",
            "Costa Rica": "San Jose",
            "Croatia": "Zagreb",
            "Cuba": "Havana",
            "Cyprus": "Nicosia",
            "Czech Republic": "Prague",
            "Denmark": "Copenhagen",
            "Djibouti": "Djibouti",
            "Dominica": "Roseau",
            "Denmark": "Copenhagen",
            "Djibouti": "Djibouti",
            "Dominica": "Roseau",
            "Dominican Republic": "Santo Domingo",
            "DR Congo": "Kinshasa",
            "East Timor": "Dili",
            "Ecuador": "Quito",
            "Egypt": "Cairo",
            "Estonia": "Tallinn",
            "Ecuador": "Quito",
            "Egypt": "Cairo",
            "El Salvador": "San Salvador",
            "Equatorial Guinea": "Malabo",
            "Eritrea": "Asmara",
            "Estonia": "Tallinn",
            "Eswatini": "Mbabane",
            "Ethiopia": "Addis Ababa",
            "European Union": "Brussels",
            "Falkland Islands": "Stanley",
            "Faroe Islands": "Torshavn",
            "Fiji": "Suva",
            "Finland": "Helsinki",
            "France": "Paris",
            "Gabon": "Libreville",
            "Gambia": "Banjul",
            "Georgia": "Tbilisi",
            "Germany": "Berlin",
            "Ghana": "Accra",
            "Gibraltar": "Gibraltar",
            "Greece": "Athens",
            "Greenland": "Nuuk",
            "Grenada": "Saint George's",
            "Guatemala": "Guatemala City",
            "Guinea": "Conakry",
            "Guinea-Bissau": "Bissau",
            "Guyana": "Georgetown",
            "Guam": "Hagatna",
            "Guinea": "Conakry",
            "Guinea-Bissau": "Bissau",
            "Guyana": "Georgetown",
            "Haiti": "Port-au-Prince",
            "Honduras": "Tegucigalpa",
            "Hungary": "Budapest",
            "Iceland": "Reykjavik",
            "India": "New Delhi",
            "Indonesia": "Jakarta",
            "Iran": "Tehran",
            "Iraq": "Baghdad",
            "Ireland": "Dublin",
            "Israel": "Jerusalem",
            "Isle of Man": "Douglas",
            "Italy": "Rome",
            "Ivory Coast": "Yamoussoukro",
            "Jamaica": "Kingston",
            "Japan": "Tokyo",
            "Jordan": "Amman",
            "Kazakhstan": "Astana",
            "Kenya": "Nairobi",
            "Kiribati": "Tarawa",
            "Kuwait": "Kuwait City",
            "Kyrgyzstan": "Bishkek",
            "Laos": "Vientiane",
            "Latvia": "Riga",
            "Lebanon": "Beirut",
            "Lesotho": "Maseru",
            "Liberia": "Monrovia",
            "Libya": "Tripoli",
            "Liechtenstein": "Vaduz",
            "Lithuania": "Vilnius",
            "Luxembourg": "Luxembourg",
            "Macau": "Macau",
            "Macedonia": "Skopje",
            "Madagascar": "Antananarivo",
            "Malawi": "Lilongwe",
            "Malaysia": "Kuala Lumpur",
            "Maldives": "Male",
            "Mali": "Bamako",
            "Malta": "Valletta",
            "Marshall Islands": "Majuro",
            "Mauritania": "Nouakchott",
            "Mauritius": "Port Louis",
            "Mexico": "Mexico City",
            "Micronesia": "Palikir",
            "Moldova": "Chisinau",
            "Monaco": "Monaco",
            "Mongolia": "Ulaanbaatar",
            "Montenegro": "Podgorica",
            "Morocco": "Rabat",
            "Monserrat": "Plymouth",
            "Mozambique": "Maputo",
            "Myanmar": "Naypyidaw",
            "Namibia": "Windhoek",
            "Nauru": "Yaren",
            "Nepal": "Kathmandu",
            "Netherlands": "Amsterdam",
            "New Caledonia": "Noumea",
            "New Zealand": "Wellington",
            "Nicaragua": "Managua",
            "Niger": "Niamey",
            "Nigeria": "Abuja",
            "Niue": "Alofi",
            "Norway": "Oslo",
            "North Korea": "Pyongyang",
            "North Macedonia": "Skopje",
            "Oman": "Muscat",
            "Pakistan": "Islamabad",
            "Palau": "Melekeok",
            "Palestine": "Ramallah",
            "Panama": "Panama City",
            "Papua New Guinea": "Port Moresby",
            "Paraguay": "Asuncion",
            "Oman": "Muscat",
            "Pakistan": "Islamabad",
            "Palau": "Melekeok",
            "Panama": "Panama City",
            "Papua New Guinea": "Port Moresby",
            "Paraguay": "Asuncion",
            "Peru": "Lima",
            "Philippines": "Manila",
            "Poland": "Warsaw",
            "Portugal": "Lisbon",
            "Puerto Rico": "San Juan",
            "Qatar": "Doha",
            "Romania": "Bucharest",
            "Russia": "Moscow",
            "Rwanda": "Kigali",
            "Palau": "Melekeok",
            "Samoa": "Apia",
            "San Marino": "San Marino",
            "Sao Tome and Principe": "Sao Tome",
            "Saudi Arabia": "Riyadh",
            "Senegal": "Dakar",
            "Serbia": "Belgrade",
            "Seychelles": "Victoria",
            "Sierra Leone": "Freetown",
            "Singapore": "Singapore",
            "Slovakia": "Bratislava",
            "Slovenia": "Ljubljana",
            "Solomon Islands": "Honiara",
            "Somalia": "Mogadishu",
            "South Africa": "Pretoria",
            "South Korea": "Seoul",
            "South Sudan": "Juba",
            "Spain": "Madrid",
            "Sri Lanka": "Colombo",
            "Sudan": "Khartoum",
            "Suriname": "Paramaribo",
            "Swaziland": "Mbabane",
            "Sweden": "Stockholm",
            "Switzerland": "Bern",
            "Syria": "Damascus",
            "Taiwan": "Taipei",
            "Tajikistan": "Dushanbe",
            "Tanzania": "Dodoma",
            "Thailand": "Bangkok",
            "Timor-Leste": "Dili",
            "Togo": "Lome",
            "Tonga": "Nuku'alofa",
            "Turkey": "Ankara",
            "Trinidad and Tobago": "Port of Spain",
            "Tunisia": "Tunis",
            "Turkey": "Ankara",
            "Trinidad and Tobago": "Port of Spain",
            "Tunisia": "Tunis",
            "United Kingdom": "London",
            "Uruguay": "Montevideo",
            "USA": "Washington, D.C.",
            "Uzbekistan": "Tashkent",
            "Vanuatu": "Port Vila",
            "Vatican City": "Vatican City",
            "Venezuela": "Caracas",
            "Vietnam": "Hanoi",
            "West Sahara": "El-Aaiun",
            "Yemen": "Sanaa",
            "Zambia": "Lusaka",
            "Zimbabwe": "Harare",
        }

        self.player1_score = 0
        self.player2_score = 0
        self.current_player = 1


    def play_round(self):
        # Select random countries and capitals
        country_pairs = random.sample(list(self.countries_capitals.items()), 3)
        country_keys = [country for country,capital in country_pairs]

        # Shuffle country keys for better presentation
        random.shuffle(country_keys)

        print(f"\nPlayer {self.current_player}'s turn")
        print(f"Guess the capital for these countries: {', '.join(country_keys)}")

        for country, capital in country_pairs:
          start_time = time.time()
          guess = input(f"Capital of {country}: ")
          end_time = time.time()

          if guess.lower() == capital.lower():
              if end_time - start_time <= 30:
                  print("Correct! +2 points (within 30 seconds).")
                  if self.current_player == 1:
                      self.player1_score += 2
                  else:
                      self.player2_score += 2
              else:
                  print("Correct! +1 points (Exceeded 30 seconds).")
                  if self.current_player == 1:
                      self.player1_score += 1
                  else:
                      self.player2_score += 1

          else:
              print(f"Incorrect. The capital of {country} is {capital}")

        self.current_player = 3 - self.current_player  #Switch Players


    def play_game(self):
        num_rounds = 2 #you can change the number of rounds
        for _ in range(num_rounds):
            self.play_round()
            print("\nScore:")
            print(f"Player 1: {self.player1_score}")
            print(f"Player 2: {self.player2_score}")

        if self.player1_score > self.player2_score:
            print("\nPlayer 1 wins!")
        elif self.player2_score > self.player1_score:
            print("\nPlayer 2 wins!")
        else:
            print("\nIt's a tie!")


if __name__ == "__main__":
    game = AlphabetMemoryGame()
    game.play_game()

# Thanks to Patrick Frey/Strus | Geetha Pardheev | Krystyna-Szybalska | Arpan
# Bhowmick | Alex Berezkin | Alex Golub
# Out:
# Player 1's turn
# Guess the capital for these countries: Cyprus, Oman, Canada
# Capital of Canada: Ottawa
# Correct! +1 points (Exceeded 10 seconds).
# Capital of Oman: Muscat
# Correct! +1 points (Exceeded 10 seconds).
# Capital of Cyprus: turkey
# Incorrect. The capital of Cyprus is Nicosia
#
# Score:
# Player 1: 2
# Player 2: 0
#
# Player 2's turn
# Guess the capital for these countries: Cambodia, Kyrgyzstan, Mali
# Capital of Cambodia: dina
# Incorrect. The capital of Cambodia is Phnom Penh
# Capital of Kyrgyzstan: bishek
# Incorrect. The capital of Kyrgyzstan is Bishkek
# Capital of Mali: bamako
# Correct! +1 points (Exceeded 10 seconds).
#
# Score:
# Player 1: 2
# Player 2: 1
#
# Player 1 wins!
